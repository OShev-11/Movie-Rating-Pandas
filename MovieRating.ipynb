# %% [markdown]
# <a href="https://colab.research.google.com/github/OShev-11/Movie-Rating/blob/main/MovieRating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba12ad33-8cf7-4f48-a401-456501bf01ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba12ad33-8cf7-4f48-a401-456501bf01ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
rating = pd.read_csv('ratings.csv')
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
rating.sort_values(by=['rating', 'timestamp'], ascending=[False, False]).head(5)
# Out:
#        userId  movieId  rating   timestamp
# 30174     210   177765     5.0  1537632257
# 46600     305   148671     5.0  1537354985
# 51318     331    57669     5.0  1537235356
# 51314     331    55820     5.0  1537235354
# 51202     331      608     5.0  1537235353
